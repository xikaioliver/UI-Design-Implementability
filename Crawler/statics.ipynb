# %%
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_csv("result_2.csv", sep=',')
data.rename(columns={'Unnamed: 0':'component'}, inplace = True)

# %%
dict = {}
for i in range(data.shape[0]):
    key = data.iloc[i]['component'].partition('.')[0]
    if key in dict:
        dict[key] += data.iloc[i]['num']
    else:
        dict[key] = data.iloc[i]['num']

# %%
statics = pd.DataFrame(dict, index=['num'])
# statics = statics.reset_index()
statics
# Out:
#      me   com  de  br  nerd  info  subreddit  org  aarddict  androidx  \
# num   7  1177  53   1     6     3          1  347         2        47
#
#         ...      community  cn  link  mozilla  ca  sk  nodomain  zame  \
# num     ...             27   1     3        1   4   5         2    11
#
#      Internal  defpackage
# num         3           1
#
# [1 rows x 72 columns]

# %%
# statics.columns = ['type', 'num']
plt.figure(figsize=(5,5))
plt.pie(statics.iloc[0,:],radius=1,labels=statics.columns)
# plt.pie(data.iloc[1,:],radius=0.7,wedgeprops=dict(width=0.3,edgecolor='w'),colors=['r','g','b','y'])
# Out:
# ([<matplotlib.patches.Wedge at 0x10ab76be0>,
#   <matplotlib.patches.Wedge at 0x10ab7e0f0>,
#   <matplotlib.patches.Wedge at 0x10ab7e630>,
#   <matplotlib.patches.Wedge at 0x10ab7eb70>,
#   <matplotlib.patches.Wedge at 0x10ab880f0>,
#   <matplotlib.patches.Wedge at 0x10ab88630>,
#   <matplotlib.patches.Wedge at 0x10ab88b70>,
#   <matplotlib.patches.Wedge at 0x10ab910f0>,
#   <matplotlib.patches.Wedge at 0x10ab91630>,
#   <matplotlib.patches.Wedge at 0x10ab91b70>,
#   <matplotlib.patches.Wedge at 0x118a617f0>,
#   <matplotlib.patches.Wedge at 0x118f585f8>,
#   <matplotlib.patches.Wedge at 0x118f58b38>,
#   <matplotlib.patches.Wedge at 0x118f630b8>,
#   <matplotlib.patches.Wedge at 0x118f635f8>,
#   <matplotlib.patches.Wedge at 0x118f63b38>,
#   <matplotlib.patches.Wedge at 0x118f6a0b8>,
#   <matplotlib.patches.Wedge at 0x118f6a5f8>,
#   <matplotlib.patches.Wedge at 0x118f6ab38>,
#   <matplotlib.patches.Wedge at 0x118f750b8>,
#   <matplotlib.patches.Wedge at 0x118f755f8>,
#   <matplotlib.patches.Wedge at 0x118f75b38>,
#   <matplotlib.patches.Wedge at 0x118f7e0b8>,
#   <matplotlib.patches.Wedge at 0x118f7e5f8>,
#   <matplotlib.patches.Wedge at 0x118f7eb38>,
#   <matplotlib.patches.Wedge at 0x118f880b8>,
#   <matplotlib.patches.Wedge at 0x118f885f8>,
#   <matplotlib.patches.Wedge at 0x118f88b38>,
#   <matplotlib.patches.Wedge at 0x118f910b8>,
#   <matplotlib.patches.Wedge at 0x118f915f8>,
#   <matplotlib.patches.Wedge at 0x118f91b38>,
#   <matplotlib.patches.Wedge at 0x118fd70b8>,
#   <matplotlib.patches.Wedge at 0x118fd75f8>,
#   <matplotlib.patches.Wedge at 0x118fd7b38>,
#   <matplotlib.patches.Wedge at 0x118fe20b8>,
#   <matplotlib.patches.Wedge at 0x118fe25f8>,
#   <matplotlib.patches.Wedge at 0x118fe2b38>,
#   <matplotlib.patches.Wedge at 0x118feb0b8>,
#   <matplotlib.patches.Wedge at 0x118feb5f8>,
#   <matplotlib.patches.Wedge at 0x118febb38>,
#   <matplotlib.patches.Wedge at 0x118ff40b8>,
#   <matplotlib.patches.Wedge at 0x118ff45f8>,
#   <matplotlib.patches.Wedge at 0x118ff4b38>,
#   <matplotlib.patches.Wedge at 0x118ffd0b8>,
#   <matplotlib.patches.Wedge at 0x118ffd5f8>,
#   <matplotlib.patches.Wedge at 0x118ffdb38>,
#   <matplotlib.patches.Wedge at 0x1190050b8>,
#   <matplotlib.patches.Wedge at 0x1190055f8>,
#   <matplotlib.patches.Wedge at 0x119005b38>,
#   <matplotlib.patches.Wedge at 0x1190110b8>,
#   <matplotlib.patches.Wedge at 0x1190115f8>,
#   <matplotlib.patches.Wedge at 0x119011b38>,
#   <matplotlib.patches.Wedge at 0x11901a0b8>,
#   <matplotlib.patches.Wedge at 0x11901a5f8>,
#   <matplotlib.patches.Wedge at 0x11901ab38>,
#   <matplotlib.patches.Wedge at 0x1190210b8>,
#   <matplotlib.patches.Wedge at 0x1190215f8>,
#   <matplotlib.patches.Wedge at 0x119021b38>,
#   <matplotlib.patches.Wedge at 0x11902b0b8>,
#   <matplotlib.patches.Wedge at 0x11902b5f8>,
#   <matplotlib.patches.Wedge at 0x11902bb38>,
#   <matplotlib.patches.Wedge at 0x1190330b8>,
#   <matplotlib.patches.Wedge at 0x1190335f8>,
#   <matplotlib.patches.Wedge at 0x119033b38>,
#   <matplotlib.patches.Wedge at 0x11903e0b8>,
#   <matplotlib.patches.Wedge at 0x11903e5f8>,
#   <matplotlib.patches.Wedge at 0x11903eb38>,
#   <matplotlib.patches.Wedge at 0x1190460b8>,
#   <matplotlib.patches.Wedge at 0x1190465f8>,
#   <matplotlib.patches.Wedge at 0x119046b38>,
#   <matplotlib.patches.Wedge at 0x11904d0b8>,
#   <matplotlib.patches.Wedge at 0x11904d5f8>],
#  [Text(1.09994,0.0118986,'me'),
#   Text(-0.293038,1.06025,'com'),
#   Text(-0.908132,-0.620722,'de'),
#   Text(-0.853236,-0.694254,'br'),
#   Text(-0.845676,-0.703443,'nerd'),
#   Text(-0.835811,-0.715136,'info'),
#   Text(-0.831375,-0.720288,'subreddit'),
#   Text(-0.345088,-1.04447,'org'),
#   Text(0.240273,-1.07344,'aarddict'),
#   Text(0.320787,-1.05219,'androidx'),
#   Text(0.432506,-1.0114,'io'),
#   Text(0.572899,-0.939035,'net'),
#   Text(0.672275,-0.870658,'haibison'),
#   Text(0.697545,-0.850547,'dev'),
#   Text(0.722214,-0.829703,'kiwi'),
#   Text(0.724774,-0.827467,'li'),
#   Text(0.729875,-0.822972,'in'),
#   Text(0.734948,-0.818444,'gq'),
#   Text(0.737474,-0.816169,'mehdi'),
#   Text(0.74125,-0.812741,'rikka'),
#   Text(0.747507,-0.80699,'jp'),
#   Text(0.756193,-0.798857,'ch'),
#   Text(0.763567,-0.791812,'im'),
#   Text(0.772087,-0.783506,'calculator'),
#   Text(0.781714,-0.773901,'agency'),
#   Text(0.792401,-0.762955,'afzkl'),
#   Text(0.800608,-0.754339,'indrora'),
#   Text(0.802935,-0.751861,'souch'),
#   Text(0.823535,-0.729239,'pl'),
#   Text(0.851086,-0.696888,'be'),
#   Text(0.872214,-0.670256,'yuku'),
#   Text(0.888518,-0.648488,'se'),
#   Text(0.899412,-0.633291,'filter'),
#   Text(0.911952,-0.615097,'gs'),
#   Text(0.925045,-0.595225,'core'),
#   Text(0.933233,-0.582302,'update'),
#   Text(0.935028,-0.579415,'adblocker'),
#   Text(0.939477,-0.572174,'mobi'),
#   Text(0.956709,-0.54287,'fr'),
#   Text(0.971437,-0.516052,'no'),
#   Text(0.994309,-0.470479,'uk'),
#   Text(1.01764,-0.417612,'es'),
#   Text(1.02644,-0.3955,'us'),
#   Text(1.0336,-0.3764,'lecho'),
#   Text(1.03647,-0.368402,'cz'),
#   Text(1.03873,-0.361989,'ru'),
#   Text(1.0442,-0.345895,'douzifly'),
#   Text(1.05144,-0.323225,'eu'),
#   Text(1.05536,-0.310202,'krasilnikov'),
#   Text(1.05725,-0.303673,'likeanimation'),
#   Text(1.05911,-0.297132,'uz'),
#   Text(1.0627,-0.284017,'at'),
#   Text(1.06613,-0.270858,'giraffine'),
#   Text(1.06696,-0.267562,'activities'),
#   Text(1.06779,-0.264263,'biz'),
#   Text(1.069,-0.25931,'nl'),
#   Text(1.07325,-0.241102,'github'),
#   Text(1.0772,-0.222825,'ryey'),
#   Text(1.07822,-0.217829,'rehanced'),
#   Text(1.07921,-0.212828,'koeln'),
#   Text(1.08083,-0.204483,'it'),
#   Text(1.08207,-0.197798,'mbmb5'),
#   Text(1.08961,-0.150808,'community'),
#   Text(1.09512,-0.103536,'cn'),
#   Text(1.09574,-0.0967651,'link'),
#   Text(1.09631,-0.0899903,'mozilla'),
#   Text(1.09698,-0.0815171,'ca'),
#   Text(1.098,-0.0662533,'sk'),
#   Text(1.09866,-0.0543724,'nodomain'),
#   Text(1.09953,-0.0322922,'zame'),
#   Text(1.09997,-0.00849913,'Internal'),
#   Text(1.1,-0.0016999,'defpackage')])

# %%
statics = statics.T.reset_index()
statics.columns = ['type', 'num']

# %%
statics.sort_values(by = 'num',axis = 0,ascending = False)
# Out:
#            type   num
# 1           com  1177
# 7           org   347
# 11          net    70
# 2            de    53
# 9      androidx    47
# 40           uk    28
# 62    community    27
# 10           io    23
# 13          dev    18
# 28           pl    17
# 38           fr    16
# 30         yuku    12
# 69         zame    11
# 56       github     9
# 34         core     8
# 29           be     8
# 42           us     8
# 51           at     7
# 47           eu     7
# 46     douzifly     7
# 32       filter     7
# 0            me     7
# 4          nerd     6
# 33           gs     6
# 41           es     6
# 25        afzkl     6
# 23   calculator     5
# 67           sk     5
# 31           se     4
# 66           ca     4
# ..          ...   ...
# 57         ryey     2
# 59        koeln     2
# 68     nodomain     2
# 19        rikka     2
# 39           no     2
# 55           nl     2
# 8      aarddict     2
# 22           im     2
# 65      mozilla     1
# 63           cn     1
# 61        mbmb5     1
# 58     rehanced     1
# 36    adblocker     1
# 54          biz     1
# 18        mehdi     1
# 3            br     1
# 6     subreddit     1
# 12     haibison     1
# 14         kiwi     1
# 15           li     1
# 17           gq     1
# 26      indrora     1
# 53   activities     1
# 27        souch     1
# 35       update     1
# 44           cz     1
# 48  krasilnikov     1
# 50           uz     1
# 52    giraffine     1
# 71   defpackage     1
#
# [72 rows x 2 columns]

# %%
data.sort_values(by = ['num'],axis = 0,ascending = False)
# Out:
#                                               component  num
# 274      com.simplemobiletools.commons.views.MyTextView  232
# 466   com.simplemobiletools.calendar.views.SmallMont...   24
# 56    com.pes.androidmaterialcolorpickerdialog.Mater...   24
# 130           com.github.clans.fab.FloatingActionButton   18
# 1311  uk.co.ashtonbrsc.intentexplode.widget.Underlin...   17
# 273          com.simplemobiletools.commons.views.PinTab   16
# 931        com.llamacorp.equate.view.AnimatedHoldButton   12
# 107   net.margaritov.preference.colorpicker.ColorPic...   12
# 55                de.we.acaldav.widget.IconfiedEditText   10
# 869      de.delusions.measure.components.MeasureDisplay   10
# 61    com.actionbarsherlock.internal.widget.ActionBa...    9
# 1312  uk.co.ashtonbrsc.intentexplode.widget.BlockEnt...    9
# 191                   androidx.appcompat.widget.Toolbar    9
# 1242  com.greenaddress.greenbits.ui.FontAwesomeTextView    9
# 500     com.mikepenz.materialdrawer.view.BezelImageView    9
# 62    com.actionbarsherlock.internal.widget.ActionBa...    8
# 59    com.actionbarsherlock.internal.widget.ActionBa...    8
# 383                    yuku.ambilwarna.AmbilWarnaSquare    8
# 740              org.connectbot.views.CheckableMenuItem    7
# 278   com.simplemobiletools.commons.views.MyCompatRa...    7
# 412                io.codetail.widget.RevealFrameLayout    7
# 723          fr.free.nrw.commons.ui.widget.HtmlTextView    7
# 64    com.actionbarsherlock.internal.nineoldandroids...    6
# 106   net.margaritov.preference.colorpicker.ColorPic...    6
# 60    com.actionbarsherlock.internal.nineoldandroids...    6
# 911                     com.andexert.library.RippleView    5
# 193        dev.dworks.apps.anexplorer.ui.CompatTextView    5
# 900               com.sovworks.eds.android.views.EditSB    5
# 1325          com.teleca.jamendo.widget.RemoteImageView    5
# 910    pl.hypeapp.episodie.ui.widget.DrawerMenuItemView    5
# ...                                                 ...  ...
# 482   com.codetroopers.betterpickers.radialtimepicke...    1
# 479         com.squareup.timessquare.CalendarPickerView    1
# 511   es.usc.citius.servando.calendula.util.view.Par...    1
# 478          com.larswerkman.holocolorpicker.OpacityBar    1
# 477               com.larswerkman.holocolorpicker.SVBar    1
# 476   uk.co.yahoo.p1rpp.calendartrigger.activites.Fi...    1
# 472   com.simplemobiletools.calendar.views.MonthView...    1
# 471       com.simplemobiletools.commons.views.MySeekBar    1
# 470   com.simplemobiletools.calendar.views.WeeklyVie...    1
# 469   com.simplemobiletools.calendar.views.MyScrollView    1
# 490     com.antonyt.infiniteviewpager.InfiniteViewPager    1
# 492    com.codetroopers.betterpickers.hmspicker.HmsView    1
# 493               com.roomorama.caldroid.SquareTextView    1
# 494            com.squareup.timessquare.CalendarRowView    1
# 510   com.codetroopers.betterpickers.recurrencepicke...    1
# 509   com.codetroopers.betterpickers.recurrencepicke...    1
# 508                     com.roomorama.caldroid.CellView    1
# 507   com.codetroopers.betterpickers.calendardatepic...    1
# 506   com.codetroopers.betterpickers.numberpicker.Nu...    1
# 505   com.codetroopers.betterpickers.widget.AutoScro...    1
# 504   es.usc.citius.servando.calendula.pinlock.view....    1
# 503   es.usc.citius.servando.calendula.pinlock.view....    1
# 502   com.codetroopers.betterpickers.timepicker.Time...    1
# 501   com.codetroopers.betterpickers.calendardatepic...    1
# 499           com.squareup.timessquare.CalendarGridView    1
# 498                  com.squareup.timessquare.MonthView    1
# 497   com.codetroopers.betterpickers.widget.Accessib...    1
# 496   com.codetroopers.betterpickers.widget.Accessib...    1
# 495           com.squareup.timessquare.CalendarCellView    1
# 1353                      com.fsck.k9.view.ViewSwitcher    1
#
# [1354 rows x 2 columns]
