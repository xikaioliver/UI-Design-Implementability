# %%
import xml.sax
 
class LayoutHandler( xml.sax.ContentHandler ):
#    def __init__(self):
#       self.CurrentData = ""
 
   # 元素开始事件处理
   def startElement(self, tag, attributes):
      print(tag + '{', end = "")
 
   # 元素结束事件处理
   def endElement(self, tag):
      print('}', end = "")
 
    # 内容事件处理
#    def characters(self, content):
#     if content != "":
#         print(content, end="")
#       if self.CurrentData == "type":
#          self.type = content
#       elif self.CurrentData == "format":
#          self.format = content
#       elif self.CurrentData == "year":
#          self.year = content
#       elif self.CurrentData == "rating":
#          self.rating = content
#       elif self.CurrentData == "stars":
#          self.stars = content
#       elif self.CurrentData == "description":
#          self.description = content

# %%
import os

# %%
list = os.listdir()
list
# Out:
# ['abc_action_bar_view_list_nav_layout.xml',
#  'home_activity.xml',
#  'date_time_dialog.xml',
#  'call_taxi_fragment.xml',
#  'datepicker.xml',
#  'abc_list_menu_item_checkbox.xml',
#  'restore_user_activity.xml',
#  'menu_fragment.xml',
#  'design_layout_snackbar_include.xml',
#  'place_autocomplete_item_prediction.xml',
#  'abc_alert_dialog_button_bar_material.xml',
#  'address_place_search_fragment.xml',
#  'place_list_item.xml',
#  'abc_activity_chooser_view_list_item.xml',
#  'alertdialog_edittext.xml',
#  'agenda_list_row.xml',
#  'paypal_manage_activity.xml',
#  'paypal_plus_cards_activity.xml',
#  'notification_template_big_media.xml',
#  'design_layout_tab_icon.xml',
#  'abc_screen_content_include.xml',
#  'abc_activity_chooser_view.xml',
#  'abc_select_dialog_material.xml',
#  'abc_action_bar_title_item.xml',
#  'favorite_list.xml',
#  'messenger_button_send_white_round.xml',
#  'toast_terminal.xml',
#  'credit_card_add_fields_zoop.xml',
#  'abc_screen_toolbar.xml',
#  'abc_dialog_title_material.xml',
#  'abc_search_view.xml',
#  'abc_search_dropdown_item_icons_2line.xml',
#  'abc_action_menu_item_layout.xml',
#  'design_bottom_sheet_dialog.xml',
#  'com_facebook_activity_layout.xml',
#  'paypal_plus_setup_activity.xml',
#  'abc_action_bar_up_container.xml',
#  'login_fragment.xml',
#  'abc_list_menu_item_layout.xml',
#  'password_prompt.xml',
#  'datetimepicker.xml',
#  'signup_fragment.xml',
#  'design_navigation_item_separator.xml',
#  'title_detail_list_row.xml',
#  'com_facebook_tooltip_bubble.xml',
#  'default_toolbar.xml',
#  'notification_media_cancel_action.xml',
#  'timepicker.xml',
#  'forgot_password_activity.xml',
#  'easy_geo_location_row.xml',
#  'messenger_button_send_blue_small.xml',
#  'paypal_setup_activity.xml',
#  'favorite_list_fragment.xml',
#  'abc_action_menu_layout.xml',
#  'confirm_corporate_registry_data_activity.xml',
#  'messenger_button_send_blue_large.xml',
#  'notification_template_lines.xml',
#  'place_autocomplete_fragment.xml',
#  'notification_template_part_time.xml',
#  'abc_list_menu_item_radio.xml',
#  'favorite_list_row.xml',
#  'signup_activity_include.xml',
#  'pin_validation_activity.xml',
#  'signup_activity.xml',
#  'partner_list_row.xml',
#  'login_activity.xml',
#  'credit_card_add_activity.xml',
#  'credit_card_add_scan_activity.xml',
#  'abc_screen_simple_overlay_action_mode.xml',
#  'address_search_fragment.xml',
#  'login_tabs_activity.xml',
#  'abc_popup_menu_item_layout.xml',
#  'favorites_activity.xml',
#  'credit_card_add_fields.xml',
#  'splash_screen_activity.xml',
#  'design_menu_item_action_area.xml',
#  'select_dialog_singlechoice_material.xml',
#  'set_password_activity.xml',
#  'select_dialog_item_material.xml',
#  'call_taxi_preferences_activity.xml',
#  'design_navigation_menu.xml',
#  'corporate_login_fragment.xml',
#  'address_list_row.xml',
#  'messenger_button_send_white_small.xml',
#  'call_status_fragment.xml',
#  'messenger_button_send_white_large.xml',
#  'corporate_login_activity.xml',
#  'support_simple_spinner_dropdown_item.xml',
#  'notification_media_action.xml',
#  'notification_template_media.xml',
#  'abc_alert_dialog_material.xml',
#  'credit_card_add_activity_zoop.xml',
#  'design_navigation_item.xml',
#  'abc_action_mode_bar.xml',
#  'app_simple_list_item.xml',
#  'navigation_drawer_fragment.xml',
#  'design_navigation_item_header.xml',
#  'locate_address_fragment.xml',
#  'map_web_view.xml',
#  'address_search_activity.xml',
#  'easy_geo_activity.xml',
#  '.ipynb_checkpoints',
#  'design_layout_snackbar.xml',
#  'abc_action_mode_close_item_material.xml',
#  'agenda_list.xml',
#  'spinner_item.xml',
#  'design_navigation_item_subheader.xml',
#  'abc_list_menu_item_icon.xml',
#  'map_fragment.xml',
#  'multiple_rating_item.xml',
#  'abc_expanded_menu_layout.xml',
#  'activity_main.xml',
#  'generic_list.xml',
#  'place_autocomplete_progress.xml',
#  'toast_airplane.xml',
#  'agenda_detail_fragment.xml',
#  'favorite_list_check_row.xml',
#  'Analysis.ipynb',
#  'credit_card_list_check_row.xml',
#  'partner_list_activity.xml',
#  'place_autocomplete_item_powered_by_google.xml',
#  'messenger_button_send_blue_round.xml',
#  'com_facebook_login_fragment.xml',
#  'map_activity.xml',
#  'design_navigation_menu_item.xml',
#  'call_taxi_company_activity.xml',
#  'multiple_rating_dialog.xml',
#  'notification_template_big_media_narrow.xml',
#  'com_facebook_device_auth_dialog_fragment.xml',
#  'notification_template_part_chronometer.xml',
#  'call_taxi_payment_activity.xml',
#  'credit_card_list.xml',
#  'abc_screen_simple.xml',
#  'select_dialog_multichoice_material.xml',
#  'fragment_conteiner.xml',
#  'design_layout_tab_text.xml']

# %%
# 创建一个 XMLReader
parser = xml.sax.make_parser()
# turn off namepsaces
parser.setFeature(xml.sax.handler.feature_namespaces, 0)
# 重写 ContextHandler
Handler = LayoutHandler()
parser.setContentHandler( Handler )
for name in list:
    if name.endswith('.xml'):
        print(name)
        parser.parse(name)
        print()
# Out:
# abc_action_bar_view_list_nav_layout.xml
# LinearLayout{}
# home_activity.xml
# LinearLayout{FrameLayout{}}
# date_time_dialog.xml
# RelativeLayout{com.ptashek.widgets.datetimepicker.DateTimePicker{}LinearLayout{Button{}Button{}Button{}}}
# call_taxi_fragment.xml
# ScrollView{LinearLayout{LinearLayout{LinearLayout{EditText{}EditText{}}LinearLayout{EditText{}}LinearLayout{CheckBox{}EditText{}}}LinearLayout{LinearLayout{TextView{}EditText{}}LinearLayout{TextView{}LinearLayout{ImageButton{}EditText{}ImageButton{}}}TextView{}RadioGroup{RadioButton{}RadioButton{}}LinearLayout{LinearLayout{ImageView{}TextView{}TextView{}}LinearLayout{ImageView{}TextView{}TextView{}}LinearLayout{ImageView{}TextView{}TextView{}}LinearLayout{ImageView{}TextView{}TextView{}}}LinearLayout{Switch{}}LinearLayout{LinearLayout{LinearLayout{TextView{}Spinner{}}LinearLayout{TextView{}Spinner{}}}LinearLayout{CheckBox{}}LinearLayout{CheckBox{}}LinearLayout{CheckBox{}}LinearLayout{CheckBox{}}LinearLayout{RadioGroup{RadioButton{}RadioButton{}}LinearLayout{TextView{}Spinner{}}}LinearLayout{TextView{}EditText{}}LinearLayout{TextView{}EditText{}}LinearLayout{TextView{}Spinner{}}LinearLayout{TextView{}Spinner{}}LinearLayout{TextView{}Spinner{}}LinearLayout{TextView{}EditText{}Spinner{}}LinearLayout{TextView{}EditText{}Spinner{}}LinearLayout{TextView{}EditText{}}LinearLayout{TextView{}Spinner{}}LinearLayout{TextView{}Spinner{}}LinearLayout{TextView{}EditText{}}}TextView{}Button{}ImageView{}}}}
# datepicker.xml
# LinearLayout{DatePicker{}}
# abc_list_menu_item_checkbox.xml
# CheckBox{}
# restore_user_activity.xml
# LinearLayout{include{}LinearLayout{TextView{}EditText{}TextView{}EditText{}TextView{}EditText{}Button{}}}
# menu_fragment.xml
# LinearLayout{ScrollView{LinearLayout{Button{}Button{}Button{}Button{}FrameLayout{Button{}ImageView{}}}}LinearLayout{TextView{}Button{}}}
# design_layout_snackbar_include.xml
# merge{TextView{}Button{}}
# place_autocomplete_item_prediction.xml
# RelativeLayout{include{}View{}TextView{}TextView{}}
# abc_alert_dialog_button_bar_material.xml
# android.support.v7.widget.ButtonBarLayout{Button{}android.support.v4.widget.Space{}Button{}Button{}}
# address_place_search_fragment.xml
# LinearLayout{LinearLayout{FrameLayout{LinearLayout{EditText{}}FrameLayout{Button{}}}}FrameLayout{ListView{}}}
# place_list_item.xml
# LinearLayout{TextView{}TextView{}}
# abc_activity_chooser_view_list_item.xml
# LinearLayout{LinearLayout{ImageView{}TextView{}}}
# alertdialog_edittext.xml
# LinearLayout{EditText{}}
# agenda_list_row.xml
# LinearLayout{TextView{}TextView{}}
# paypal_manage_activity.xml
# LinearLayout{include{}ImageView{}LinearLayout{TextView{}Button{}}LinearLayout{TextView{}Button{}TextView{}}}
# paypal_plus_cards_activity.xml
# LinearLayout{include{}WebView{}LinearLayout{Button{}Button{}}}
# notification_template_big_media.xml
# RelativeLayout{ImageView{}include{}include{}LinearLayout{}ImageView{}}
# design_layout_tab_icon.xml
# ImageView{}
# abc_screen_content_include.xml
# merge{android.support.v7.widget.ContentFrameLayout{}}
# abc_activity_chooser_view.xml
# view{FrameLayout{ImageView{}}FrameLayout{ImageView{}}}
# abc_select_dialog_material.xml
# ListView{}
# abc_action_bar_title_item.xml
# LinearLayout{TextView{}TextView{}}
# favorite_list.xml
# LinearLayout{TextView{}TextView{}Button{}ListView{}}
# messenger_button_send_white_round.xml
# Button{}
# toast_terminal.xml
# LinearLayout{ImageView{}TextView{}}
# credit_card_add_fields_zoop.xml
# ScrollView{LinearLayout{LinearLayout{TextView{}EditText{}}LinearLayout{TextView{}Spinner{}}LinearLayout{TextView{}EditText{}}LinearLayout{TextView{}EditText{}}LinearLayout{TextView{}EditText{}}LinearLayout{TextView{}EditText{}}LinearLayout{TextView{}LinearLayout{Spinner{}Spinner{}}}LinearLayout{TextView{}EditText{}}LinearLayout{TextView{}LinearLayout{TextView{}EditText{}}LinearLayout{TextView{}EditText{}}LinearLayout{TextView{}EditText{}}LinearLayout{TextView{}EditText{}}TextView{}LinearLayout{TextView{}EditText{}}LinearLayout{TextView{}EditText{}}LinearLayout{TextView{}EditText{}}LinearLayout{TextView{}EditText{}}LinearLayout{TextView{}EditText{}}TextView{}}LinearLayout{}LinearLayout{}Button{}}}
# abc_screen_toolbar.xml
# android.support.v7.widget.ActionBarOverlayLayout{include{}android.support.v7.widget.ActionBarContainer{android.support.v7.widget.Toolbar{}android.support.v7.widget.ActionBarContextView{}}}
# abc_dialog_title_material.xml
# android.support.v7.widget.FitWindowsLinearLayout{TextView{}include{}}
# abc_search_view.xml
# LinearLayout{TextView{}ImageView{}LinearLayout{ImageView{}LinearLayout{view{}ImageView{}}LinearLayout{ImageView{}ImageView{}}}}
# abc_search_dropdown_item_icons_2line.xml
# RelativeLayout{ImageView{}ImageView{}ImageView{}TextView{}TextView{}}
# abc_action_menu_item_layout.xml
# android.support.v7.view.menu.ActionMenuItemView{}
# design_bottom_sheet_dialog.xml
# android.support.design.widget.CoordinatorLayout{View{}FrameLayout{}}
# com_facebook_activity_layout.xml
# FrameLayout{}
# paypal_plus_setup_activity.xml
# LinearLayout{include{}ScrollView{LinearLayout{ImageView{}LinearLayout{TextView{}EditText{}EditText{}EditText{}EditText{}EditText{}Button{}}LinearLayout{TextView{}Button{}TextView{}}}}}
# abc_action_bar_up_container.xml
# LinearLayout{}
# login_fragment.xml
# LinearLayout{ScrollView{LinearLayout{com.facebook.login.widget.LoginButton{}EditText{}LinearLayout{EditText{}TextView{}Switch{}}Button{}TextView{}TextView{}}}}
# abc_list_menu_item_layout.xml
# android.support.v7.view.menu.ListMenuItemView{RelativeLayout{TextView{}TextView{}}}
# password_prompt.xml
# LinearLayout{TextView{}LinearLayout{EditText{requestFocus{}}TextView{}Switch{}}}
# datetimepicker.xml
# RelativeLayout{LinearLayout{Button{}Button{}}ViewSwitcher{}}
# signup_fragment.xml
# ScrollView{LinearLayout{LinearLayout{com.facebook.login.widget.LoginButton{}LinearLayout{EditText{}EditText{}}EditText{}LinearLayout{TextView{}RadioGroup{RadioButton{}RadioButton{}}}EditText{}EditText{}LinearLayout{LinearLayout{TextView{}EditText{}}LinearLayout{TextView{}EditText{}}}LinearLayout{LinearLayout{EditText{}TextView{}Switch{}}}LinearLayout{TextView{}LinearLayout{TextView{}EditText{}}LinearLayout{TextView{}EditText{}}}Button{}TextView{}TextView{}}LinearLayout{TextView{}EditText{}LinearLayout{Button{}Button{}}TextView{}}}}
# design_navigation_item_separator.xml
# FrameLayout{View{}}
# title_detail_list_row.xml
# LinearLayout{TextView{}TextView{}}
# com_facebook_tooltip_bubble.xml
# RelativeLayout{RelativeLayout{ImageView{}TextView{}}ImageView{}ImageView{}}
# default_toolbar.xml
# android.support.v7.widget.Toolbar{}
# notification_media_cancel_action.xml
# ImageButton{}
# timepicker.xml
# LinearLayout{TimePicker{}}
# forgot_password_activity.xml
# LinearLayout{include{}LinearLayout{TextView{}EditText{}Button{}}}
# easy_geo_location_row.xml
# LinearLayout{TextView{}}
# messenger_button_send_blue_small.xml
# FrameLayout{TextView{}}
# paypal_setup_activity.xml
# LinearLayout{include{}WebView{}}
# favorite_list_fragment.xml
# LinearLayout{ListView{}}
# abc_action_menu_layout.xml
# android.support.v7.widget.ActionMenuView{}
# confirm_corporate_registry_data_activity.xml
# LinearLayout{include{}LinearLayout{EditText{}EditText{}LinearLayout{EditText{}EditText{}}EditText{}EditText{}Button{}}}
# messenger_button_send_blue_large.xml
# FrameLayout{TextView{}}
# notification_template_lines.xml
# LinearLayout{LinearLayout{TextView{}include{}include{}}TextView{}LinearLayout{TextView{}TextView{}}}
# place_autocomplete_fragment.xml
# LinearLayout{ImageButton{}EditText{}ImageButton{}}
# notification_template_part_time.xml
# DateTimeView{}
# abc_list_menu_item_radio.xml
# RadioButton{}
# favorite_list_row.xml
# LinearLayout{TextView{}TextView{}}
# signup_activity_include.xml
# ScrollView{LinearLayout{View{}LinearLayout{EditText{}EditText{}}EditText{}LinearLayout{TextView{}RadioGroup{RadioButton{}RadioButton{}}}EditText{}EditText{}LinearLayout{LinearLayout{TextView{}EditText{}}LinearLayout{TextView{}EditText{}}}LinearLayout{LinearLayout{EditText{}TextView{}Switch{}}LinearLayout{EditText{}}}LinearLayout{TextView{}LinearLayout{TextView{}EditText{}}LinearLayout{TextView{}EditText{}}}Button{}LinearLayout{TextView{}EditText{}LinearLayout{Button{}Button{}}TextView{}}}}
# pin_validation_activity.xml
# LinearLayout{include{}LinearLayout{TextView{}EditText{}LinearLayout{Button{}Button{}}TextView{}}}
# signup_activity.xml
# LinearLayout{include{}include{}}
# partner_list_row.xml
# LinearLayout{TextView{}TextView{}LinearLayout{ImageView{}TextView{}}}
# login_activity.xml
# LinearLayout{include{}ScrollView{LinearLayout{EditText{}LinearLayout{EditText{}TextView{}Switch{}}Button{}TextView{}TextView{}Button{}com.facebook.login.widget.LoginButton{}Button{}}}}
# credit_card_add_activity.xml
# LinearLayout{include{}FrameLayout{include{}}}
# credit_card_add_scan_activity.xml
# LinearLayout{include{}LinearLayout{FrameLayout{EditText{}TextView{}}LinearLayout{ImageView{}Button{}}LinearLayout{EditText{}EditText{}}EditText{}EditText{}Button{}TextView{}TextView{}}}
# abc_screen_simple_overlay_action_mode.xml
# android.support.v7.widget.FitWindowsFrameLayout{include{}android.support.v7.widget.ViewStubCompat{}}
# address_search_fragment.xml
# LinearLayout{LinearLayout{LinearLayout{EditText{}EditText{}}EditText{}Button{}}ProgressBar{}FrameLayout{ListView{}}}
# login_tabs_activity.xml
# LinearLayout{include{}android.support.design.widget.TabLayout{}View{}android.support.v4.view.ViewPager{}}
# abc_popup_menu_item_layout.xml
# android.support.v7.view.menu.ListMenuItemView{RelativeLayout{TextView{}TextView{}}}
# favorites_activity.xml
# LinearLayout{FrameLayout{}}
# credit_card_add_fields.xml
# ScrollView{LinearLayout{LinearLayout{TextView{}LinearLayout{TextView{}EditText{}}LinearLayout{TextView{}EditText{}}LinearLayout{TextView{}EditText{}}LinearLayout{TextView{}EditText{}}}LinearLayout{TextView{}LinearLayout{TextView{}EditText{}}LinearLayout{TextView{}EditText{}}LinearLayout{TextView{}EditText{}}LinearLayout{TextView{}EditText{}}LinearLayout{TextView{}EditText{}}LinearLayout{TextView{}EditText{}}LinearLayout{TextView{}EditText{}}}TextView{}LinearLayout{TextView{}EditText{}}LinearLayout{TextView{}Spinner{}}LinearLayout{TextView{}EditText{}}LinearLayout{TextView{}EditText{}}LinearLayout{TextView{}LinearLayout{Spinner{}Spinner{}}}LinearLayout{TextView{}EditText{}}Button{}}}
# splash_screen_activity.xml
# LinearLayout{TextView{}}
# design_menu_item_action_area.xml
# FrameLayout{}
# select_dialog_singlechoice_material.xml
# CheckedTextView{}
# set_password_activity.xml
# LinearLayout{include{}LinearLayout{TextView{}EditText{}TextView{}EditText{}EditText{}Button{}}}
# select_dialog_item_material.xml
# TextView{}
# call_taxi_preferences_activity.xml
# LinearLayout{include{}LinearLayout{LinearLayout{LinearLayout{TextView{}Spinner{}}LinearLayout{TextView{}Spinner{}}}CheckBox{}CheckBox{}CheckBox{}CheckBox{}LinearLayout{TextView{}Spinner{}}LinearLayout{TextView{}Spinner{}}FrameLayout{Button{}}}}
# design_navigation_menu.xml
# android.support.design.internal.NavigationMenuView{}
# corporate_login_fragment.xml
# LinearLayout{LinearLayout{EditText{}EditText{}Button{}TextView{}}}
# address_list_row.xml
# TextView{}
# messenger_button_send_white_small.xml
# FrameLayout{TextView{}}
# call_status_fragment.xml
# LinearLayout{LinearLayout{de.hdodenhof.circleimageview.CircleImageView{}LinearLayout{TextView{}LinearLayout{LinearLayout{TextView{}TextView{}}LinearLayout{TextView{}TextView{}}}TextView{}LinearLayout{TextView{}}}}View{}LinearLayout{TextView{}ImageButton{}EditText{}}LinearLayout{FrameLayout{FrameLayout{}ProgressBar{}}}LinearLayout{ProgressBar{}TextView{}}LinearLayout{LinearLayout{TextView{}TextView{}}LinearLayout{TextView{}TextView{}}TextView{}LinearLayout{Button{}ImageButton{}Button{}Button{}}}LinearLayout{LinearLayout{RatingBar{}EditText{}}Button{}}Button{}Button{}}
# messenger_button_send_white_large.xml
# FrameLayout{TextView{}}
# corporate_login_activity.xml
# LinearLayout{include{}LinearLayout{EditText{}EditText{}Button{}TextView{}}}
# support_simple_spinner_dropdown_item.xml
# TextView{}
# notification_media_action.xml
# ImageButton{}
# notification_template_media.xml
# LinearLayout{ImageView{}include{}LinearLayout{}include{}ImageView{}}
# abc_alert_dialog_material.xml
# LinearLayout{LinearLayout{LinearLayout{ImageView{}android.support.v7.widget.DialogTitle{}}}FrameLayout{View{}android.support.v4.widget.NestedScrollView{LinearLayout{TextView{}View{}}}View{}}FrameLayout{FrameLayout{}}include{}}
# credit_card_add_activity_zoop.xml
# LinearLayout{include{}FrameLayout{include{}}}
# design_navigation_item.xml
# android.support.design.internal.NavigationMenuItemView{}
# abc_action_mode_bar.xml
# android.support.v7.widget.ActionBarContextView{}
# app_simple_list_item.xml
# TextView{}
# navigation_drawer_fragment.xml
# LinearLayout{ScrollView{LinearLayout{View{}RelativeLayout{ImageView{}TextView{}}View{}LinearLayout{ImageView{}TextView{}}LinearLayout{ImageView{}TextView{}}LinearLayout{ImageView{}TextView{}}LinearLayout{ImageView{}TextView{}ImageView{}}LinearLayout{ImageView{}TextView{}}LinearLayout{ImageView{}TextView{}}LinearLayout{ImageView{}TextView{}}LinearLayout{ImageView{}TextView{}}LinearLayout{ImageView{}TextView{}}FrameLayout{LinearLayout{TextView{}LinearLayout{TextView{}TextView{}}TextView{}}}}}}
# design_navigation_item_header.xml
# LinearLayout{}
# locate_address_fragment.xml
# android.support.v4.app.FragmentTabHost{LinearLayout{TabWidget{}FrameLayout{}FrameLayout{}}}
# map_web_view.xml
# LinearLayout{WebView{}}
# address_search_activity.xml
# LinearLayout{include{}android.support.design.widget.TabLayout{}View{}android.support.v4.view.ViewPager{}}
# easy_geo_activity.xml
# LinearLayout{include{}LinearLayout{LinearLayout{EditText{}EditText{}}EditText{}Button{}ProgressBar{}ListView{}}}
# design_layout_snackbar.xml
# view{}
# abc_action_mode_close_item_material.xml
# ImageView{}
# agenda_list.xml
# LinearLayout{TextView{}LinearLayout{}TextView{}TextView{}ListView{}}
# spinner_item.xml
# TextView{}
# design_navigation_item_subheader.xml
# TextView{}
# abc_list_menu_item_icon.xml
# ImageView{}
# map_fragment.xml
# LinearLayout{FrameLayout{LinearLayout{LinearLayout{LinearLayout{TextView{}LinearLayout{TextView{}TextView{}TextView{}}}ImageButton{}}View{}LinearLayout{LinearLayout{TextView{}LinearLayout{TextView{}TextView{}TextView{}}}FrameLayout{ImageView{}}}}View{}View{}}LinearLayout{LinearLayout{LinearLayout{TextView{}LinearLayout{TextView{}TextView{}}}LinearLayout{TextView{}TextView{}}LinearLayout{TextView{}TextView{}}}View{}}FrameLayout{FrameLayout{}ImageView{}LinearLayout{}LinearLayout{ImageButton{}ImageButton{}ImageButton{}}FrameLayout{}LinearLayout{FrameLayout{LinearLayout{TextView{}}}FrameLayout{Button{}ImageView{}}}}}
# multiple_rating_item.xml
# LinearLayout{TextView{}RatingBar{}TextView{}}
# abc_expanded_menu_layout.xml
# android.support.v7.view.menu.ExpandedMenuView{}
# activity_main.xml
# RelativeLayout{TextView{}}
# generic_list.xml
# LinearLayout{TextView{}TextView{}ListView{}}
# place_autocomplete_progress.xml
# ProgressBar{}
# toast_airplane.xml
# LinearLayout{ImageView{}TextView{}}
# agenda_detail_fragment.xml
# ScrollView{FrameLayout{LinearLayout{LinearLayout{TextView{}TextView{}}LinearLayout{TextView{}TextView{}}LinearLayout{TextView{}TextView{}}LinearLayout{TextView{}TextView{}}LinearLayout{TextView{}TextView{}}LinearLayout{TextView{}TextView{}}LinearLayout{TextView{}TextView{}}LinearLayout{TextView{}TextView{}}LinearLayout{TextView{}TextView{}}LinearLayout{TextView{}TextView{}}LinearLayout{TextView{}TextView{}}LinearLayout{TextView{}TextView{}}Button{}}ProgressBar{}}}
# favorite_list_check_row.xml
# LinearLayout{CheckBox{}LinearLayout{TextView{}TextView{}TextView{}}}
# credit_card_list_check_row.xml
# LinearLayout{CheckBox{}LinearLayout{TextView{}TextView{}}}
# partner_list_activity.xml
# LinearLayout{include{}LinearLayout{TextView{}Spinner{}}FrameLayout{ListView{}TextView{}}}
# place_autocomplete_item_powered_by_google.xml
# RelativeLayout{View{}include{}ImageView{}}
# messenger_button_send_blue_round.xml
# Button{}
# com_facebook_login_fragment.xml
# RelativeLayout{ProgressBar{}}
# map_activity.xml
# android.support.v4.widget.DrawerLayout{LinearLayout{include{}FrameLayout{}}br.com.originalsoftware.taxifonecliente.drawer.ScrimInsetsFrameLayout{fragment{}}}
# design_navigation_menu_item.xml
# merge{CheckedTextView{}ViewStub{}}
# call_taxi_company_activity.xml
# LinearLayout{include{}LinearLayout{TextView{}LinearLayout{TextView{}Spinner{}}LinearLayout{TextView{}Spinner{}}LinearLayout{TextView{}Spinner{}}LinearLayout{TextView{}Spinner{}}LinearLayout{TextView{}EditText{}Spinner{}}LinearLayout{TextView{}EditText{}Spinner{}}FrameLayout{Button{}}}}
# multiple_rating_dialog.xml
# LinearLayout{TextView{}ScrollView{LinearLayout{}}LinearLayout{LinearLayout{LinearLayout{TextView{}TextView{}}LinearLayout{TextView{}TextView{}}}LinearLayout{TextView{}TextView{}}}CheckBox{}EditText{}}
# notification_template_big_media_narrow.xml
# RelativeLayout{ImageView{}include{}include{}LinearLayout{}ImageView{}}
# com_facebook_device_auth_dialog_fragment.xml
# android.support.v7.widget.CardView{LinearLayout{RelativeLayout{FrameLayout{ImageView{}}TextView{}ProgressBar{}}TextView{}FrameLayout{Button{}}}}
# notification_template_part_chronometer.xml
# Chronometer{}
# call_taxi_payment_activity.xml
# LinearLayout{include{}LinearLayout{LinearLayout{TextView{}Spinner{}}LinearLayout{TextView{}EditText{}}LinearLayout{TextView{}EditText{}}LinearLayout{TextView{}Spinner{}}LinearLayout{TextView{}EditText{}}ImageView{}FrameLayout{Button{}}}}
# credit_card_list.xml
# LinearLayout{Button{}Button{}ListView{}}
# abc_screen_simple.xml
# android.support.v7.widget.FitWindowsLinearLayout{android.support.v7.widget.ViewStubCompat{}include{}}
# select_dialog_multichoice_material.xml
# CheckedTextView{}
# fragment_conteiner.xml
# LinearLayout{include{}FrameLayout{}}
# design_layout_tab_text.xml
# TextView{}
